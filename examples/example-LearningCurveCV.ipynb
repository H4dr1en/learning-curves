# %%
from sklearn.datasets import make_regression
import learning_curves as LC
from learning_curves import *
from xgboost import XGBRegressor

# %%
X, Y = make_regression(1000)
model = XGBRegressor(tree_method="hist")

# %%
lc = LearningCurveCV(10)

# %%
lc.train(model, X, Y, n_splits=10)
# Out:
# [learning_curve] Training set sizes: [  8  10  12  16  21  26  34  43  55  70  90 115 146 186 238 303 386 492
#  627 800]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:    8.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [learning_curve] Training set sizes: [  8  10  12  16  21  26  34  43  55  70  90 115 146 186 238 303 386 492
#  627 800]
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:    6.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [learning_curve] Training set sizes: [  8  10  12  16  21  26  34  43  55  70  90 115 146 186 238 303 386 492
#  627 800]
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:    6.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# ...

# %%
lc.plot()

# %%
lc.lcs[0].recorder["train_sizes"]
# Out:
# array([  8,  10,  12,  16,  21,  26,  34,  43,  55,  70,  90, 115, 146,
#        186, 238, 303, 386, 492, 627, 800])

# %%
lc.target(100000)
# Out:
# (array([0.86206118]), array([0.15791392]))

# %%
lc.fit_all()

# %%
lc.plot_all(figsize=(18,12), target=int(1e2), predictor="best", what="valid", ylim=(0,1))

# %%
lc.target(5000000)
# Out:
# (array([0.97238155]), array([0.01358786]))

# %%
 LearningCurve.compare_time(lc.lcs, what="fit")
